# %%
import pandas as pd

# %%
s = pd.Series([1,2,3,4,5],name ="marks")

# %%
print(type(s))
# Out:
# <class 'pandas.Series'>

# %%
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: marks, dtype: int64

# %%
print(s.mean())
# Out:
# 3.0

# %% [markdown]
# **DataFrame**

# %%
data = {
    "Name":["Alice",'Bob',"Charlie","David"],
    "Age":[24,27,22,32],
    "Score": [85,71,78,91]
}
print(type(data))
print(data)
# Out:
# <class 'dict'>
# {'Name': ['Alice', 'Bob', 'Charlie', 'David'], 'Age': [24, 27, 22, 32], 'Score': [85, 71, 78, 91]}

# %%
df = pd.DataFrame(data)

# %%
print(type(df))
print(df)
# Out:
# <class 'pandas.DataFrame'>
#       Name  Age  Score
# 0    Alice   24     85
# 1      Bob   27     71
# 2  Charlie   22     78
# 3    David   32     91

# %%
print(df.head())
print("----------------------")
print(df.tail())
# Out:
#       Name  Age  Score
# 0    Alice   24     85
# 1      Bob   27     71
# 2  Charlie   22     78
# 3    David   32     91
# ----------------------
#       Name  Age  Score
# 0    Alice   24     85
# 1      Bob   27     71
# 2  Charlie   22     78
# 3    David   32     91

# %%
df.to_csv("sample.csv",index= False)

# %% [markdown]
# **Read data from a CSV file**

# %%
df1 = pd.read_csv("sample.csv")

print(df1)
# Out:
#       Name  Age  Score
# 0    Alice   24     85
# 1      Bob   27     71
# 2  Charlie   22     78
# 3    David   32     91

# %%
df1.shape
# Out:
# (4, 3)

# %%
df1.columns
# Out:
# Index(['Name', 'Age', 'Score'], dtype='str')

# %%
df.head()
# Out:
#       Name  Age  Score
# 0    Alice   24     85
# 1      Bob   27     71
# 2  Charlie   22     78
# 3    David   32     91

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      str
#  1   Age     4 non-null      int64
#  2   Score   4 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 228.0 bytes

# %% [markdown]
# **Inspecting the Data**

# %%
print(df1.shape)
print(df1.columns)
print(df1.dtypes)
# Out:
# (4, 3)
# Index(['Name', 'Age', 'Score'], dtype='str')
# Name       str
# Age      int64
# Score    int64
# dtype: object

# %%
#single column
print(type(df1["Name"]))
print(df1["Name"])
# Out:
# <class 'pandas.Series'>
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# Name: Name, dtype: str

# %%
#multiple columns
print(df[["Name","Age"]])
# Out:
#       Name  Age
# 0    Alice   24
# 1      Bob   27
# 2  Charlie   22
# 3    David   32

# %%
#row selection:
print(df.iloc[1]) #by index
# Out:
# Name     Bob
# Age       27
# Score     71
# Name: 1, dtype: object

# %%
print(df.loc[0])   #by label
# Out:
# Name     Alice
# Age         24
# Score       85
# Name: 0, dtype: object

# %%
data = {
    "Name": ['Anna','Ben','Cara','Dana'],
    'Score':[81,82,59,70]
}

# %%
df2 = pd.DataFrame(data, index=['a','b','c','d'])

# %%
df2.head()
# Out:
#    Name  Score
# a  Anna     81
# b   Ben     82
# c  Cara     59
# d  Dana     70

# %%
df2.iloc[1]
# Out:
# Name     Ben
# Score     82
# Name: b, dtype: object

# %%
df2.loc['b']
# Out:
# Name     Ben
# Score     82
# Name: b, dtype: object

# %% [markdown]
# **Filtering Data**

# %%
df
# Out:
#       Name  Age  Score
# 0    Alice   24     85
# 1      Bob   27     71
# 2  Charlie   22     78
# 3    David   32     91

# %%
high_scores = df[df['Score']>84]
print(high_scores)
# Out:
#     Name  Age  Score
# 0  Alice   24     85
# 3  David   32     91

# %% [markdown]
# **Adding new column**

# %%
df["Passed"] = df["Score"] >84
print(df)
# Out:
#       Name  Age  Score  Passed
# 0    Alice   24     85    True
# 1      Bob   27     71   False
# 2  Charlie   22     78   False
# 3    David   32     91    True

# %%
df["Score_Percentage"] = df["Score"] / 100*100

# %%
df
# Out:
#       Name  Age  Score  Passed  Score_Percentage
# 0    Alice   24     85    True              85.0
# 1      Bob   27     71   False              71.0
# 2  Charlie   22     78   False              78.0
# 3    David   32     91    True              91.0

# %%
df["city"] = ["Pune","Mumbai","Lucknow","Jaipur"]

# %%
df
# Out:
#       Name  Age  Score  Passed  Score_Percentage     city
# 0    Alice   24     85    True              85.0     Pune
# 1      Bob   27     71   False              71.0   Mumbai
# 2  Charlie   22     78   False              78.0  Lucknow
# 3    David   32     91    True              91.0   Jaipur

# %% [markdown]
# **Descriptive Statistics**

# %%
print(df["Score"].mean())
print(df["Score"].max())
print(df["Score"].min())
# Out:
# 81.25
# 91
# 71

# %%
df.describe()
# Out:
#              Age      Score  Score_Percentage
# count   4.000000   4.000000          4.000000
# mean   26.250000  81.250000         81.250000
# std     4.349329   8.655441          8.655441
# min    22.000000  71.000000         71.000000
# 25%    23.500000  76.250000         76.250000
# 50%    25.500000  81.500000         81.500000
# 75%    28.250000  86.500000         86.500000
# max    32.000000  91.000000         91.000000

# %% [markdown]
# **Handling missing data**

# %%
df2 = pd.DataFrame(
    {
    "Name":["Alice",None,"Charlie","David"],
    "Age":[24,27,22,None],
    "Score": [None,71,78,91]
    }
)

# %%
df2.dropna(subset=["Name"], inplace=True)

# %%
df2.head()
# Out:
#       Name   Age  Score
# 0    Alice  24.0    NaN
# 2  Charlie  22.0   78.0
# 3    David   NaN   91.0

# %%
df2['Age'] = df2['Age'].fillna(df2['Age'].mean())
df2['Score'] = df2['Score'].fillna(df2['Score'].mean())

# %%
df2
# Out:
#       Name   Age  Score
# 0    Alice  24.0   84.5
# 2  Charlie  22.0   78.0
# 3    David  23.0   91.0

# %% [markdown]
# **Sorting**

# %%
df2.sort_values(by="Score", ascending=False)
# Out:
#       Name   Age  Score
# 3    David  23.0   91.0
# 0    Alice  24.0   84.5
# 2  Charlie  22.0   78.0

# %% [markdown]
# **Filtering using multiple conditions:**

# %%
df
# Out:
#       Name  Age  Score  Passed  Score_Percentage     city
# 0    Alice   24     85    True              85.0     Pune
# 1      Bob   27     71   False              71.0   Mumbai
# 2  Charlie   22     78   False              78.0  Lucknow
# 3    David   32     91    True              91.0   Jaipur

# %%
df[(df["Score"] > 80) & (df["Age"] > 22)]
# Out:
#     Name  Age  Score  Passed  Score_Percentage    city
# 0  Alice   24     85    True              85.0    Pune
# 3  David   32     91    True              91.0  Jaipur
